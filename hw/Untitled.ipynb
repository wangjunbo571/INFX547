# %%
import pandas as pd

# %%
pd.__version__
# Out:
# u'0.19.2'

# %%
#Import the necessary methods from tweepy library
import sys
import time
import datetime
import pandas as pd

from tweepy import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API

#Fill in your twitter dev info.
consumer_key = '9qfh9E7NytEJir0x8DPhA0Wo3'
consumer_secret = 'KXrazhottbw0htNyaz8ghC7JiPvmbuunqmDToqp1fGoqX2Cwa0'

access_token ='775111751108923392-0i4ZTsWb11OgIBSI9ZoA7noTLdUwSQI'
access_token_secret = 'prMoEZkGgvgOaWwI9WOlHuaNr4D6jkQPhZkWkh8ZPuxJo'

#This handles Twitter authetification and the connection to Twitter Streaming API
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = API(auth)

#Print received tweets to stdout

class StreamParser(StreamListener):
    """ Controls how streaming data is parsed. Pass an outfile, or data will be writting to 
    sys.stdout (eg the screen)
    """
    def __init__(self, outfile=None, max_tweets=5, max_seconds=30):
        self.counter = 0
        self.start_time = time.time()
        # Set upper limits on maximum tweets or seconds before timeout
        self.max_tweets = max_tweets
        self.max_seconds = max_seconds
        if outfile:
            self.stdout = open(outfile, 'w')
        else:
            self.stdout = sys.stdout
    
    def on_data(self, data):
        """ Data is a string, but formatted for json. Parses it"""
        self.counter += 1
        # time data is all timestamps.
        current_time = time.time()
        run_time = current_time - self.start_time
                
        # If we want to read time, easiest way is to convert from timestamp using datetime
        formatted_time = datetime.datetime.now()
            
        # Technically, might not be the best place to put kill statements, but works well enough
        if self.max_tweets:
            if self.counter > self.max_tweets:
                self._kill_stdout()
                raise SystemExit('Max tweets of %s exceeded.  Killing stream... see %s' \
                             % (self.max_tweets, self.stdout))
  
        if self.max_seconds:
            if run_time > self.max_seconds:
                self._kill_stdout()
                raise SystemExit('Max time of %s seconds exceeded.  Killing stream... see %s' \
                                 % (self.max_seconds, self.stdout))

        print ('Tweet %s at %s.\nEllapsed: %.2f seconds\n' %(self.counter, formatted_time, run_time))

        # Write to file, return True causes stream to continue I guess...
        self.stdout.write(data)
        return True

    def _kill_stdout(self):
        """ If self.stdout is a file, close it.  If sys.stdout, pass"""
        if self.stdout is not sys.stdout:
            self.stdout.close() 
    
    def on_error(self, status):
        print (status)

# Stream 10 tweets, no matter the time it takes!
listener = StreamParser(outfile='infx547d4.json', max_tweets=20, max_seconds=None)
stream = Stream(auth, listener)

#This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
stream.filter(track=['Seattle'])
# Out:
# Tweet 1 at 2017-05-11 15:03:50.384741.
# Ellapsed: 4.53 seconds
#
# Tweet 2 at 2017-05-11 15:03:51.123164.
# Ellapsed: 5.27 seconds
#
# Tweet 3 at 2017-05-11 15:03:52.427654.
# Ellapsed: 6.58 seconds
#
# Tweet 4 at 2017-05-11 15:03:52.868828.
# Ellapsed: 7.02 seconds
#
# Tweet 5 at 2017-05-11 15:03:53.300742.
# Ellapsed: 7.45 seconds
#
# Tweet 6 at 2017-05-11 15:03:56.585275.
# Ellapsed: 10.73 seconds
#
# Tweet 7 at 2017-05-11 15:03:59.709230.
# Ellapsed: 13.86 seconds
#
# Tweet 8 at 2017-05-11 15:04:00.153797.
# Ellapsed: 14.30 seconds
#
# Tweet 9 at 2017-05-11 15:04:00.268443.
# Ellapsed: 14.42 seconds
#
# Tweet 10 at 2017-05-11 15:04:00.423728.
# Ellapsed: 14.57 seconds
#
# Tweet 11 at 2017-05-11 15:04:01.202675.
# Ellapsed: 15.35 seconds
#
# Tweet 12 at 2017-05-11 15:04:01.900609.
# Ellapsed: 16.05 seconds
#
# Tweet 13 at 2017-05-11 15:04:04.879923.
# Ellapsed: 19.03 seconds
#
# Tweet 14 at 2017-05-11 15:04:06.954416.
# Ellapsed: 21.10 seconds
#
# Tweet 15 at 2017-05-11 15:04:07.174669.
# Ellapsed: 21.32 seconds
#
# Tweet 16 at 2017-05-11 15:04:10.075445.
# Ellapsed: 24.22 seconds
#
# Tweet 17 at 2017-05-11 15:04:10.695810.
# Ellapsed: 24.84 seconds
#
# Tweet 18 at 2017-05-11 15:04:11.421130.
# Ellapsed: 25.57 seconds
#
# Tweet 19 at 2017-05-11 15:04:13.290412.
# Ellapsed: 27.44 seconds
#
# Tweet 20 at 2017-05-11 15:04:14.531389.
# Ellapsed: 28.68 seconds
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Max tweets of 20 exceeded.  Killing stream... see <closed file 'infx547d4.json', mode 'w' at 0x7f2c2565cf60>

# %%
data = pd.read_json('infx547d4.json', lines=True)
data
# Out:
#     contributors  coordinates          created_at display_text_range  \
# 0            NaN          NaN 2017-05-11 22:03:47           [0, 108]
# 1            NaN          NaN 2017-05-11 22:03:48                NaN
# 2            NaN          NaN 2017-05-11 22:03:49                NaN
# 3            NaN          NaN 2017-05-11 22:03:50                NaN
# 4            NaN          NaN 2017-05-11 22:03:50                NaN
# 5            NaN          NaN 2017-05-11 22:03:54                NaN
# 6            NaN          NaN 2017-05-11 22:03:57                NaN
# 7            NaN          NaN 2017-05-11 22:03:57                NaN
# 8            NaN          NaN 2017-05-11 22:03:57                NaN
# 9            NaN          NaN 2017-05-11 22:03:57                NaN
# 10           NaN          NaN 2017-05-11 22:03:58            [0, 97]
# 11           NaN          NaN 2017-05-11 22:03:59           [16, 30]
# 12           NaN          NaN 2017-05-11 22:04:02           [0, 109]
# 13           NaN          NaN 2017-05-11 22:04:04                NaN
# 14           NaN          NaN 2017-05-11 22:04:04                NaN
# 15           NaN          NaN 2017-05-11 22:04:07           [0, 140]
# 16           NaN          NaN 2017-05-11 22:04:08                NaN
# 17           NaN          NaN 2017-05-11 22:04:08                NaN
# 18           NaN          NaN 2017-05-11 22:04:10                NaN
# 19           NaN          NaN 2017-05-11 22:04:12                NaN
#
#                                              entities  \
# 0   {u'user_mentions': [{u'id': 23642374, u'indice...
# 1   {u'user_mentions': [], u'symbols': [], u'hasht...
# 2   {u'user_mentions': [], u'symbols': [], u'hasht...
# 3   {u'user_mentions': [{u'id': 64565898, u'indice...
# 4   {u'user_mentions': [], u'symbols': [], u'hasht...
# 5   {u'user_mentions': [{u'id': 39571220, u'indice...
# 6   {u'user_mentions': [], u'symbols': [], u'hasht...
# 7   {u'user_mentions': [], u'symbols': [], u'hasht...
# 8   {u'user_mentions': [{u'id': 1576165646, u'indi...
# 9   {u'user_mentions': [{u'id': 4141789941, u'indi...
# 10  {u'user_mentions': [], u'symbols': [], u'hasht...
# 11  {u'user_mentions': [{u'id': 22637974, u'indice...
# 12  {u'user_mentions': [{u'id': 47418503, u'indice...
# 13  {u'user_mentions': [], u'symbols': [], u'hasht...
# 14  {u'user_mentions': [], u'symbols': [], u'hasht...
# 15  {u'user_mentions': [], u'symbols': [], u'hasht...
# 16  {u'user_mentions': [], u'symbols': [], u'hasht...
# 17  {u'user_mentions': [], u'symbols': [], u'hasht...
# 18  {u'user_mentions': [], u'symbols': [], u'hasht...
# 19  {u'user_mentions': [], u'symbols': [], u'hasht...
#
#                                     extended_entities  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   {u'media': [{u'source_user_id': 2196127371, u'...
# 10  {u'media': [{u'expanded_url': u'https://twitte...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                        extended_tweet  favorite_count  \
# 0                                                 NaN               0
# 1                                                 NaN               0
# 2                                                 NaN               0
# 3                                                 NaN               0
# 4                                                 NaN               0
# 5                                                 NaN               0
# 6                                                 NaN               0
# 7                                                 NaN               0
# 8                                                 NaN               0
# 9                                                 NaN               0
# 10                                                NaN               0
# 11                                                NaN               0
# 12                                                NaN               0
# 13                                                NaN               0
# 14                                                NaN               0
# 15  {u'display_text_range': [0, 135], u'entities':...               0
# 16                                                NaN               0
# 17                                                NaN               0
# 18                                                NaN               0
# 19                                                NaN               0
#
#    favorited filter_level                        ...                          \
# 0      False          low                        ...
# 1      False          low                        ...
# 2      False          low                        ...
# 3      False          low                        ...
# 4      False          low                        ...
# 5      False          low                        ...
# 6      False          low                        ...
# 7      False          low                        ...
# 8      False          low                        ...
# 9      False          low                        ...
# 10     False          low                        ...
# 11     False          low                        ...
# 12     False          low                        ...
# 13     False          low                        ...
# 14     False          low                        ...
# 15     False          low                        ...
# 16     False          low                        ...
# 17     False          low                        ...
# 18     False          low                        ...
# 19     False          low                        ...
#
#     quoted_status_id  quoted_status_id_str  retweet_count retweeted  \
# 0       8.627671e+17          8.627671e+17              0     False
# 1                NaN                   NaN              0     False
# 2                NaN                   NaN              0     False
# 3       8.625970e+17          8.625970e+17              0     False
# 4                NaN                   NaN              0     False
# 5                NaN                   NaN              0     False
# 6                NaN                   NaN              0     False
# 7                NaN                   NaN              0     False
# 8       8.627861e+17          8.627861e+17              0     False
# 9                NaN                   NaN              0     False
# 10               NaN                   NaN              0     False
# 11               NaN                   NaN              0     False
# 12      8.606453e+17          8.606453e+17              0     False
# 13               NaN                   NaN              0     False
# 14               NaN                   NaN              0     False
# 15               NaN                   NaN              0     False
# 16               NaN                   NaN              0     False
# 17               NaN                   NaN              0     False
# 18               NaN                   NaN              0     False
# 19               NaN                   NaN              0     False
#
#                                      retweeted_status  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {u'contributors': None, u'truncated': False, u...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   {u'contributors': None, u'truncated': True, u'...
# 9   {u'contributors': None, u'truncated': False, u...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                
# 8      False  {u'follow_request_sent': None, u'profile_use_b...
# 9      False  {u'follow_request_sent': None, u'profile_use_b...
# 10     False  {u'follow_request_sent': None, u'profile_use_b...
# 11     False  {u'follow_request_sent': None, u'profile_use_b...
# 12     False  {u'follow_request_sent': None, u'profile_use_b...
# 13     False  {u'follow_request_sent': None, u'profile_use_b...
# 14     False  {u'follow_request_sent': None, u'profile_use_b...
# 15      True  {u'follow_request_sent': None, u'profile_use_b...
# 16     False  {u'follow_request_sent': None, u'profile_use_b...
# 17     False  {u'follow_request_sent': None, u'profile_use_b...
# 18     False  {u'follow_request_sent': None, u'profile_use_b...
# 19     False  {u'follow_request_sent': None, u'profile_use_b...
#
# [20 rows x 33 columns]

# %%
interesting_stuff = data[['text']]
interesting_stuff.to_excel('output.xls', index=False)
interesting_stuff
# Out:
#                                                  text
# 0   I'm in the Seattle area. It's practically mand...
# 1                                  Goodnight Seattle!
# 2   Weekend Seattle Events -  https://t.co/SzILTtxKfF
# 3   RT @Minecraft: Prepare for download, Switchers...
# 4   Associate, Health Systems\nSeattle, WA     #Ep...
# 5   Just entered to win tickets to @LICtour in Sea...
# 6   This Weekend: Seattle, WA - May 12 at The Suns...
# 7   Register for World Class Firearms Training at ...
# 8   RT @AriLiljenwall: Nico Lodeiro telling @ELROL...
# 9   RT @ScaryVids_: Seattle's Mystery Coke Machine...
# 10  Seattle Seahawks assigned numbers to rookies o...
# 11                     @barstoolsports 🖕🏻from Seattle
# 12  @roybelly I'm going to see Rap tonight in Seat...
# 13  [The Seattle Times] Robinson Cano scratched fr...
# 14  Seattle Police Arrest 26 Protesters After They...
# 15  Planning a trip to #Seattle? Check out these p...
# 16  This Weekend: Seattle, WA - May 13 at Bubble B...
# 17  This Weekend: Everett, WA - May 13 at LIVE IN ...
# 18  Three matchups to watch as Seattle travels to ...
# 19  Seahawks sign tight end Bryce Williams #seattl...

# %%
#format json data
for i in range(len(interesting_stuff)):
    sstr = str(data['timestamp_ms'][i]).split(".")[0]
    sstr = u'_'.join(sstr.split())
    interesting_stuff.set_value(i, 'time', sstr)    
print(interesting_stuff)
# Out:
#                                                  text                 time
# 0   I'm in the Seattle area. It's practically mand...  2017-05-11_22:03:47
# 1                                  Goodnight Seattle!  2017-05-11_22:03:48
# 2   Weekend Seattle Events -  https://t.co/SzILTtxKfF  2017-05-11_22:03:49
# 3   RT @Minecraft: Prepare for download, Switchers...  2017-05-11_22:03:50
# 4   Associate, Health Systems\nSeattle, WA     #Ep...  2017-05-11_22:03:50
# 5   Just entered to win tickets to @LICtour in Sea...  2017-05-11_22:03:54
# 6   This Weekend: Seattle, WA - May 12 at The Suns...  2017-05-11_22:03:57
# 7   Register for World Class Firearms Training at ...  2017-05-11_22:03:57
# 8   RT @AriLiljenwall: Nico Lodeiro telling @ELROL...  2017-05-11_22:03:57
# 9   RT @ScaryVids_: Seattle's Mystery Coke Machine...  2017-05-11_22:03:57
# 10  Seattle Seahawks assigned numbers to rookies o...  2017-05-11_22:03:58
# 11                     @barstoolsports 🖕🏻from Seattle  2017-05-11_22:03:59
