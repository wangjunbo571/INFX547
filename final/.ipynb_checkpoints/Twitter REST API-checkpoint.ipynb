# %%
import pandas as pd
pd.__version__
# Out:
# u'0.19.2'

# %%
# REST API
import sys
import json
import pandas as pd

#Fill in your twitter dev info.
consumer_key = '9qfh9E7NytEJir0x8DPhA0Wo3'
consumer_secret = 'KXrazhottbw0htNyaz8ghC7JiPvmbuunqmDToqp1fGoqX2Cwa0'

access_token ='775111751108923392-0i4ZTsWb11OgIBSI9ZoA7noTLdUwSQI'
access_token_secret = 'prMoEZkGgvgOaWwI9WOlHuaNr4D6jkQPhZkWkh8ZPuxJo'

import twitter
api = twitter.Api(consumer_key, consumer_secret, access_token, access_token_secret)
# print api.VerifyCredentials()

import time
now = time.strftime("%c")

query = "q=wannacrypt&result_type=recent&count=1"

data = api.GetSearch(raw_query= query)

print data
# Out:
# [Status(ID=865335141929029632, ScreenName=AndyVVPhillips, Created=Thu May 18 22:35:49 +0000 2017, Text=u"RT @Malwarebytes: What to do if you're infected with #WannaCrypt #ransomware... #cybersecurity #infosec #WannaCry https://t.co/Uporikmac1")]

# %%
result = {}
result['result'] = []
for item in data:
    result['result'].append(json.loads(item.AsJsonString()))
print json.dumps(result, indent=4)

with open('preforERD.json', 'w') as file:
    json.dump(result, file)
    
    print('data saved successfully!')
# Out:
# {
#     "result": [
#         {
#             "lang": "en",
#             "retweeted_status": {
#                 "lang": "en",
#                 "media": [
#                     {
#                         "expanded_url": "https://twitter.com/Malwarebytes/status/865309663105101825/photo/1",
#                         "sizes": {
#                             "large": {
#                                 "h": 1280,
#                                 "w": 872,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "h": 680,
#                                 "w": 463,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "h": 1200,
#                                 "w": 818,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "w": 150,
#                                 "resize": "crop"
#                             }
#                         },
#                         "url": "https://t.co/Uporikmac1",
#                         "media_url_https": "https://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg",
#                         "display_url": "pic.twitter.com/Uporikmac1",
#                         "type": "photo",
#                         "id": 865309660752076801,
#                         "media_url": "http://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg"
#                     }
#                 ],
#                 "created_at": "Thu May 18 20:54:35 +0000 2017",
#                 "hashtags": [
#                     {
#                         "text": "WannaCrypt"
#                     },
#                     {
#                         "text": "ransomware"
#                     },
#                     {
#                         "text": "cybersecurity"
#                     },
#                     {
#                         "text": "infosec"
#                     },
#                     {
#                         "text": "WannaCry"
#                     }
#                 ],
#                 "user_mentions": [],
#                 "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#                 "id_str": "865309663105101825",
#                 "urls": [],
#                 "text": "What to do if you're infected with #WannaCrypt #ransomware... #cybersecurity #infosec #WannaCry https://t.co/Uporikmac1",
#                 "retweet_count": 46,
#                 "id": 865309663105101825,
#                 "favorite_count": 24,
#                 "user": {
#                     "id": 18576042,
#                     "verified": true,
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "followers_count": 42052,
#                     "location": "Santa Clara, CA",
#                     "profile_background_color": "000000",
#                     "listed_count": 1492,
#                     "utc_offset": -25200,
#                     "statuses_count": 10003,
#                     "description": "Next-gen cybersecurity company. Need help? https://t.co/AXiApIhvmP",
#                     "friends_count": 911,
#                     "profile_link_color": "0084B4",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/860543209797148672/Vz0LnMyN_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/18576042/1481208650",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/448164873671696385/oVXn_bO5.jpeg",
#                     "screen_name": "Malwarebytes",
#                     "lang": "en",
#                     "favourites_count": 1930,
#                     "name": "Malwarebytes",
#                     "url": "https://t.co/z2bxDgHbxz",
#                     "created_at": "Sat Jan 03 08:03:33 +0000 2009",
#                     "time_zone": "Pacific Time (US & Canada)"
#                 }
#             },
#             "media": [
#                 {
#                     "expanded_url": "https://twitter.com/Malwarebytes/status/865309663105101825/photo/1",
#                     "sizes": {
#                         "large": {
#                             "h": 1280,
#                             "w": 872,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "h": 680,
#                             "w": 463,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "h": 1200,
#                             "w": 818,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "w": 150,
#                             "resize": "crop"
#                         }
#                     },
#                     "url": "https://t.co/Uporikmac1",
#                     "media_url_https": "https://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg",
#                     "display_url": "pic.twitter.com/Uporikmac1",
#                     "type": "photo",
#                     "id": 865309660752076801,
#                     "media_url": "http://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg"
#                 }
#             ],
#             "created_at": "Thu May 18 22:35:49 +0000 2017",
#             "hashtags": [
#                 {
#                     "text": "WannaCrypt"
#                 },
#                 {
#                     "text": "ransomware"
#                 },
#                 {
#                     "text": "cybersecurity"
#                 },
#                 {
#                     "text": "infosec"
#                 },
#                 {
#                     "text": "WannaCry"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "screen_name": "Malwarebytes",
#                     "id": 18576042,
#                     "name": "Malwarebytes"
#                 }
#             ],
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "id_str": "865335141929029632",
#             "urls": [],
#             "text": "RT @Malwarebytes: What to do if you're infected with #WannaCrypt #ransomware... #cybersecurity #infosec #WannaCry https://t.co/Uporikmac1",
#             "retweet_count": 46,
#             "id": 865335141929029632,
#             "user": {
#                 "lang": "en",
#                 "utc_offset": -14400,
#                 "favourites_count": 25040,
#                 "name": "Andy Phillips",
#                 "friends_count": 40,
#                 "profile_sidebar_fill_color": "000000",
#                 "created_at": "Fri Oct 10 14:11:38 +0000 2014",
#                 "profile_link_color": "1B95E0",
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/528472710712524800/Hdi5OtPj_normal.jpeg",
#                 "profile_text_color": "000000",
#                 "followers_count": 112,
#                 "screen_name": "AndyVVPhillips",
#                 "location": "New York",
#                 "profile_background_color": "000000",
#                 "statuses_count": 2260,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2821228191/1471013872",
#                 "id": 2821228191,
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "listed_count": 44
#             }
#         }
#     ]
# }
# data saved successfully!

# %%
import json

with open('preforERD.json', 'r') as file:
    data = json.load(file)
print json.dumps(data['result'], indent=4)
# Out:
# [
#     {
#         "lang": "en",
#         "retweeted_status": {
#             "lang": "en",
#             "media": [
#                 {
#                     "expanded_url": "https://twitter.com/Malwarebytes/status/865309663105101825/photo/1",
#                     "display_url": "pic.twitter.com/Uporikmac1",
#                     "url": "https://t.co/Uporikmac1",
#                     "media_url_https": "https://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1280,
#                             "resize": "fit",
#                             "w": 872
#                         },
#                         "small": {
#                             "h": 680,
#                             "resize": "fit",
#                             "w": 463
#                         },
#                         "medium": {
#                             "h": 1200,
#                             "resize": "fit",
#                             "w": 818
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "id": 865309660752076801,
#                     "media_url": "http://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg"
#                 }
#             ],
#             "created_at": "Thu May 18 20:54:35 +0000 2017",
#             "hashtags": [
#                 {
#                     "text": "WannaCrypt"
#                 },
#                 {
#                     "text": "ransomware"
#                 },
#                 {
#                     "text": "cybersecurity"
#                 },
#                 {
#                     "text": "infosec"
#                 },
#                 {
#                     "text": "WannaCry"
#                 }
#             ],
#             "user_mentions": [],
#             "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#             "id_str": "865309663105101825",
#             "urls": [],
#             "text": "What to do if you're infected with #WannaCrypt #ransomware... #cybersecurity #infosec #WannaCry https://t.co/Uporikmac1",
#             "retweet_count": 46,
#             "id": 865309663105101825,
#             "favorite_count": 24,
#             "user": {
#                 "id": 18576042,
#                 "verified": true,
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "followers_count": 42052,
#                 "location": "Santa Clara, CA",
#                 "profile_background_color": "000000",
#                 "listed_count": 1492,
#                 "utc_offset": -25200,
#                 "statuses_count": 10003,
#                 "description": "Next-gen cybersecurity company. Need help? https://t.co/AXiApIhvmP",
#                 "friends_count": 911,
#                 "profile_link_color": "0084B4",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/860543209797148672/Vz0LnMyN_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/18576042/1481208650",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/448164873671696385/oVXn_bO5.jpeg",
#                 "screen_name": "Malwarebytes",
#                 "lang": "en",
#                 "favourites_count": 1930,
#                 "name": "Malwarebytes",
#                 "url": "https://t.co/z2bxDgHbxz",
#                 "created_at": "Sat Jan 03 08:03:33 +0000 2009",
#                 "time_zone": "Pacific Time (US & Canada)"
#             }
#         },
#         "media": [
#             {
#                 "expanded_url": "https://twitter.com/Malwarebytes/status/865309663105101825/photo/1",
#                 "display_url": "pic.twitter.com/Uporikmac1",
#                 "url": "https://t.co/Uporikmac1",
#                 "media_url_https": "https://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1280,
#                         "resize": "fit",
#                         "w": 872
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 463
#                     },
#                     "medium": {
#                         "h": 1200,
#                         "resize": "fit",
#                         "w": 818
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "id": 865309660752076801,
#                 "media_url": "http://pbs.twimg.com/media/DAIyjUXXYAEhavS.jpg"
#             }
#         ],
#         "created_at": "Thu May 18 22:35:49 +0000 2017",
#         "hashtags": [
#             {
#                 "text": "WannaCrypt"
#             },
#             {
#                 "text": "ransomware"
#             },
#             {
#                 "text": "cybersecurity"
#             },
#             {
#                 "text": "infosec"
#             },
#             {
#                 "text": "WannaCry"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "screen_name": "Malwarebytes",
#                 "name": "Malwarebytes",
#                 "id": 18576042
#             }
#         ],
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "id_str": "865335141929029632",
#         "urls": [],
#         "text": "RT @Malwarebytes: What to do if you're infected with #WannaCrypt #ransomware... #cybersecurity #infosec #WannaCry https://t.co/Uporikmac1",
#         "retweet_count": 46,
#         "id": 865335141929029632,
#         "user": {
#             "lang": "en",
#             "utc_offset": -14400,
#             "favourites_count": 25040,
#             "name": "Andy Phillips",
#             "friends_count": 40,
#             "profile_link_color": "1B95E0",
#             "created_at": "Fri Oct 10 14:11:38 +0000 2014",
#             "profile_sidebar_fill_color": "000000",
#             "time_zone": "Eastern Time (US & Canada)",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/528472710712524800/Hdi5OtPj_normal.jpeg",
#             "profile_text_color": "000000",
#             "followers_count": 112,
#             "location": "New York",
#             "profile_background_color": "000000",
#             "statuses_count": 2260,
#             "listed_count": 44,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2821228191/1471013872",
#             "id": 2821228191,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "screen_name": "AndyVVPhillips"
#         }
#     }
# ]

# %%
# export to excel
import pandas as pd

with open('preforERD.json', 'r') as file:
    pd_data = pd.read_json(json.dumps(data['result']))

    print pd_data

pd_data.to_csv('test.csv')
# Out:
#            created_at                                           hashtags  \
# 0 2017-05-18 22:35:49  [{u'text': u'WannaCrypt'}, {u'text': u'ransomw...
#
#                    id              id_str lang  \
# 0  865335141929029632  865335141929029632   en
#
#                                                media  retweet_count  \
# 0  [{u'expanded_url': u'https://twitter.com/Malwa...             46
#
#                                     retweeted_status  \
# 0  {u'lang': u'en', u'media': [{u'expanded_url': ...
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                 text urls  \
# 0  RT @Malwarebytes: What to do if you're infecte...   []
#
#                                                 user  \
# 0  {u'lang': u'en', u'utc_offset': -14400, u'favo...
#
#                                        user_mentions
# 0  [{u'id': 18576042, u'screen_name': u'Malwareby...
